# %%
from PIL import Image
import os, random

import copy
import cv2
import pandas as pd
import matplotlib.pyplot as plt
import torch
import torch.nn.utils.prune as prune
import torchvision.transforms as transforms
import torchvision.models as models

from mytorch import *

# %%
cuda_available =  torch.cuda.is_available()
print('torch version:', torch.__version__)
print('cuda available:', cuda_available)
if cuda_available:
    print('-> cuda version:', torch.version.cuda)
    print('-> cuda device:', torch.cuda.get_device_name())
device = torch.device("cuda:0" if cuda_available else "cpu")
# Out:
# torch version: 1.10.1+cu113
# cuda available: True
# -> cuda version: 11.3
# -> cuda device: Quadro P2000

# %%
loader = transforms.Compose([
	transforms.Resize(128),  # 缩放
	transforms.ToTensor()
]) 

def get_image_info(root = 'dataset'):
	## kaggle: Grapevine Disease Images
	## https://www.kaggle.com/datasets/piyushmishra1999/plantvillage-grape
	## 取得檔案的位置、類別並分組
    dir = [x for x in os.listdir(root) if not os.path.isfile(x)]
    info = pd.DataFrame()
    for (i, f) in enumerate(dir):
        f_files = [x for x in os.listdir(os.path.join(root, f)) if not os.path.isfile(x)]
        f_info = pd.DataFrame({
            'name':[f]*len(f_files), 
            'loc':[i]*len(f_files), 
            'file':[os.path.join(root, f, x) for x in f_files], 
            'group':random.choices(['train', 'valid', 'test'], [6, 2, 2], k=len(f_files))
        })
        info = pd.concat([info, f_info])
    return info

def _image_loader(image_name):
	image = Image.open(image_name)
	image = loader(image).unsqueeze(0)
	return image

def _get_image_x(x_data):
	x_data = x_data['file'].to_list()
	x_tensor = torch.tensor([])
	for x_d in x_data:
		x_image = _image_loader(x_d)
		x_tensor = torch.cat([x_tensor, x_image])
	return x_tensor

def _get_image_y(y_data, total=4):
	y_data = y_data['loc'].to_list()
	y_tensor = torch.tensor([])
	for y_d in y_data:
		y_list = [0.0] * total
		y_list[int(y_d)] = 1.0
		y_list = torch.tensor([y_list])
		y_tensor = torch.cat([y_tensor, y_list])
	return y_tensor

def get_image_data(info):
	data_train, data_valid, data_test = map(lambda x: info[info['group'] == x], ('train', 'valid', 'test'))
	x_train, x_valid, x_test = map(lambda x: _get_image_x(x), (data_train, data_valid, data_test))
	y_train, y_valid, y_test = map(lambda y: _get_image_y(y), (data_train, data_valid, data_test))
	return x_train, y_train, x_valid, y_valid, x_test, y_test

# %%
info = get_image_info()
x_train, y_train, x_valid, y_valid, x_test, y_test = get_image_data(info)

print(x_train.size(), y_train.size())
print(x_valid.size(), y_valid.size())
print(x_test.size(), y_test.size())
# Out:
# torch.Size([2424, 3, 128, 128]) torch.Size([2424, 4])
# torch.Size([824, 3, 128, 128]) torch.Size([824, 4])
# torch.Size([814, 3, 128, 128]) torch.Size([814, 4])

# %%
model = gvd_detect()
train_dl = torch.utils.data.DataLoader(torch.utils.data.TensorDataset(x_train, y_train), shuffle=True, batch_size=64, pin_memory=True)
valid_dl = torch.utils.data.DataLoader(torch.utils.data.TensorDataset(x_valid, y_valid), shuffle=True, batch_size=64, pin_memory=True)
test_dl = torch.utils.data.DataLoader(torch.utils.data.TensorDataset(x_test, y_test), shuffle=True, batch_size=64, pin_memory=True)

criterion = torch.nn.MSELoss(reduction='mean')
criterion = criterion.to(device)
optimizer = torch.optim.Adam(model.parameters())

# %%
maxVA = 0
maxVA_ep = 0

epoch = 200
for e in range(epoch):
    ep = e+1
    model.train()
    model = model.to(device)
    for xb, yb in train_dl:
        loss = criterion(model(xb.to(device)), yb.to(device))
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
    ## 模型評估
    model.eval()
    model = model.to(torch.device('cpu'))
    train_predict = torch.tensor([])
    train_result = torch.tensor([])
    for xb, yb in train_dl:
        train_predict = torch.cat([train_predict, model(xb)], 0)
        train_result = torch.cat([train_result, yb], 0)
    valid_predict = torch.tensor([])
    valid_result = torch.tensor([])
    for xb, yb in valid_dl:
        valid_predict = torch.cat([valid_predict, model(xb)], 0)
        valid_result = torch.cat([valid_result, yb], 0)
    
    train_loss = float(criterion(train_predict, train_result))
    valid_loss = float(criterion(valid_predict, valid_result))
    train_accu = float(accuracy(train_predict, train_result))
    valid_accu = float(accuracy(valid_predict, valid_result))

    save = ''
    if (maxVA < valid_accu) | (maxVA_ep < 1):
        maxVA = valid_accu
        maxVA_ep = ep
        save = '< save'
        torch.save(model, 'gvd_detect.pt')
    print('{:<4d}'.format(ep), 
        'train_loss', '{:.4f}'.format(train_loss), 
        'train_accu', '{:.4f}'.format(train_accu), 
        'valid_loss', '{:.4f}'.format(valid_loss), 
        'valid_accu', '{:.4f}'.format(valid_accu), 
        save)
    ## early drop
    if ep < 100: ## 至少執行100次
        pass
    elif maxVA_ep < ep/2: ## 連續一半epoch的準確度小於maxValAcc
        print('Accuracy of validation is CRASH !!')
        break
print('Training done, save model at valid_accu =', maxVA)
# Out:
# 1    train_loss 0.1256 train_accu 0.6196 valid_loss 0.1286 valid_accu 0.6359 < save
# 2    train_loss 0.1221 train_accu 0.6134 valid_loss 0.1222 valid_accu 0.6032
# 3    train_loss 0.0959 train_accu 0.7327 valid_loss 0.0951 valid_accu 0.7269 < save
# 4    train_loss 0.0658 train_accu 0.8172 valid_loss 0.0679 valid_accu 0.7973 < save
# 5    train_loss 0.0380 train_accu 0.9047 valid_loss 0.0420 valid_accu 0.8859 < save
# 6    train_loss 0.0319 train_accu 0.9163 valid_loss 0.0370 valid_accu 0.9017 < save
# 7    train_loss 0.0263 train_accu 0.9319 valid_loss 0.0329 valid_accu 0.9138 < save
# 8    train_loss 0.0278 train_accu 0.9241 valid_loss 0.0371 valid_accu 0.8956
# 9    train_loss 0.0206 train_accu 0.9472 valid_loss 0.0293 valid_accu 0.9187 < save
# 10   train_loss 0.0359 train_accu 0.9043 valid_loss 0.0429 valid_accu 0.8786
# 11   train_loss 0.0176 train_accu 0.9542 valid_loss 0.0256 valid_accu 0.9320 < save
# 12   train_loss 0.0158 train_accu 0.9587 valid_loss 0.0271 valid_accu 0.9248
# 13   train_loss 0.0094 train_accu 0.9777 valid_loss 0.0197 valid_accu 0.9442 < save
# 14   train_loss 0.0175 train_accu 0.9563 valid_loss 0.0325 valid_accu 0.9114
train_loss 0.0000 train_accu 1.0000 valid_loss 0.0125 valid_accu 0.9697
# 114  train_loss 0.0001 train_accu 0.9996 valid_loss 0.0094 valid_accu 0.9782
# 115  train_loss 0.0001 train_accu 1.0000 valid_loss 0.0163 valid_accu 0.9624
# 116  train_loss 0.0005 train_accu 0.9992 valid_loss 0.0159 valid_accu 0.9648
# 117  train_loss 0.0000 train_accu 1.0000 valid_loss 0.0110 valid_accu 0.9745
# 118  train_loss 0.0000 train_accu 1.0000 valid_loss 0.0108 valid_accu 0.9757
# 119  train_loss 0.0000 train_accu 1.0000 valid_loss 0.0078 valid_accu 0.9806
# 120  train_loss 0.0003 train_accu 0.9992 valid_loss 0.0131 valid_accu 0.9697
# 121  train_loss 0.0005 train_accu 0.9988 valid_loss 0.0105 valid_accu 0.9745
# 122  train_loss 0.0009 train_accu 0.9979 valid_loss 0.0164 valid_accu 0.9600
# 123  train_loss 0.0004 train_accu 0.9992 valid_loss 0.0158 valid_accu 0.9648
# 124  train_loss 0.0004 train_accu 0.9988 valid_loss 0.0080 valid_accu 0.9782
# 125  train_loss 0.0000 train_accu 1.0000 valid_loss 0.0129 valid_accu 0.9697
# 126  train_loss 0.0000 train_accu 1.0000 valid_loss 0.0062 valid_accu 0.9867 < save
# 127  train_loss 0.0000 train_accu 1.0000 valid_loss 0.0101 valid_accu 0.9782
# 128  train_loss 0.0000 train_accu 1.0000 valid_loss 0.0081 valid_accu 0.9818
# 129  train_loss 0.0005 train_accu 0.9988 valid_loss 0.0131 valid_accu 0.9709
# 130  train_loss 0.0000 train_accu 1.0000 valid_loss 0.0081 valid_accu 0.9794
# 131  train_loss 0.0000 train_accu 1.0000 valid_loss 0.0090 valid_accu 0.9806
# 132  train_loss 0.0000 train_accu 1.0000 valid_loss 0.0079 valid_accu 0.9830
# 133  train_loss 0.0000 train_accu 1.0000 valid_loss 0.0118 valid_accu 0.9709
# 134  train_loss 0.0000 train_accu 1.0000 valid_loss 0.0088 valid_accu 0.9757
# 135  train_loss 0.0000 train_accu 1.0000 valid_loss 0.0104 valid_accu 0.9757
# 136  train_loss 0.0001 train_accu 0.9996 valid_loss 0.0118 valid_accu 0.9709
# 137  train_loss 0.0000 train_accu 1.0000 valid_loss 0.0082 valid_accu 0.9782
# 138  train_loss 0.0001 train_accu 0.9996 valid_loss 0.0095 valid_accu 0.9782
# 139  train_loss 0.0000 train_accu 1.0000 valid_loss 0.0092 valid_accu 0.9782
# 140  train_loss 0.0000 train_accu 1.0000 valid_loss 0.0100 valid_accu 0.9745
# 141  train_loss 0.0000 train_accu 1.0000 valid_loss 0.0108 valid_accu 0.9745
# 142  train_loss 0.0000 train_accu 1.0000 valid_loss 0.0075 valid_accu 0.9818
# 143  train_loss 0.0000 train_accu 1.0000 valid_loss 0.0079 valid_accu 0.9806
# 144  train_loss 0.0000 train_accu 1.0000 valid_loss 0.0070 valid_accu 0.9818
# 145  train_loss 0.0000 train_accu 1.0000 valid_loss 0.0082 valid_accu 0.9794
# 146  train_loss 0.0006 train_accu 0.9988 valid_loss 0.0178 valid_accu 0.9587
# 147  train_loss 0.0000 train_accu 1.0000 valid_loss 0.0070 valid_accu 0.9842
# 148  train_loss 0.0001 train_accu 0.9996 valid_loss 0.0126 valid_accu 0.9672
# 149  train_loss 0.0001 train_accu 1.0000 valid_loss 0.0103 valid_accu 0.9757
# 150  train_loss 0.0000 train_accu 1.0000 valid_loss 0.0058 valid_accu 0.9879 < save
# 151  train_loss 0.0007 train_accu 0.9979 valid_loss 0.0173 valid_accu 0.9612
# 152  train_loss 0.0002 train_accu 0.9992 valid_loss 0.0114 valid_accu 0.9745
# 153  train_loss 0.0006 train_accu 0.9988 valid_loss 0.0076 valid_accu 0.9818
# 154  train_loss 0.0000 train_accu 1.0000 valid_loss 0.0107 valid_accu 0.9721
# 155  train_loss 0.0000 train_accu 1.0000 valid_loss 0.0118 valid_accu 0.9733
# 156  train_loss 0.0000 train_accu 1.0000 valid_loss 0.0102 valid_accu 0.9769
# 157  train_loss 0.0001 train_accu 0.9996 valid_loss 0.0102 valid_accu 0.9745
# 158  train_loss 0.0000 train_accu 1.0000 valid_loss 0.0088 valid_accu 0.9782
# 159  train_loss 0.0000 train_accu 1.0000 valid_loss 0.0076 valid_accu 0.9818
# 160  train_loss 0.0001 train_accu 0.9996 valid_loss 0.0107 valid_accu 0.9757
# 161  train_loss 0.0000 train_accu 1.0000 valid_loss 0.0063 valid_accu 0.9842
# 162  train_loss 0.0000 train_accu 1.0000 valid_loss 0.0067 valid_accu 0.9842
# 163  train_loss 0.0000 train_accu 1.0000 valid_loss 0.0072 valid_accu 0.9842
# 164  train_loss 0.0000 train_accu 1.0000 valid_loss 0.0095 valid_accu 0.9769
# 165  train_loss 0.0000 train_accu 1.0000 valid_loss 0.0085 valid_accu 0.9818
# 166  train_loss 0.0000 train_accu 1.0000 valid_loss 0.0095 valid_accu 0.9757
# 167  train_loss 0.0000 train_accu 1.0000 valid_loss 0.0144 valid_accu 0.9624
# 168  train_loss 0.0000 train_accu 1.0000 valid_loss 0.0094 valid_accu 0.9782
# 169  train_loss 0.0001 train_accu 0.9996 valid_loss 0.0135 valid_accu 0.9684
# 170  train_loss 0.0001 train_accu 0.9996 valid_loss 0.0103 valid_accu 0.9782
# 171  train_loss 0.0000 train_accu 1.0000 valid_loss 0.0082 valid_accu 0.9794
# 172  train_loss 0.0000 train_accu 1.0000 valid_loss 0.0064 valid_accu 0.9854
# 173  train_loss 0.0000 train_accu 1.0000 valid_loss 0.0074 valid_accu 0.9830
# 174  train_loss 0.0000 train_accu 1.0000 valid_loss 0.0075 valid_accu 0.9806
# 175  train_loss 0.0000 train_accu 1.0000 valid_loss 0.0068 valid_accu 0.9830
# 176  train_loss 0.0000 train_accu 1.0000 valid_loss 0.0048 valid_accu 0.9903 < save
# 177  train_loss 0.0000 train_accu 1.0000 valid_loss 0.0099 valid_accu 0.9757
# 178  train_loss 0.0000 train_accu 1.0000 valid_loss 0.0056 valid_accu 0.9867
# 179  train_loss 0.0000 train_accu 1.0000 valid_loss 0.0126 valid_accu 0.9697
# 180  train_loss 0.0000 train_accu 1.0000 valid_loss 0.0060 valid_accu 0.9842
# 181  train_loss 0.0000 train_accu 1.0000 valid_loss 0.0081 valid_accu 0.9818
# 182  train_loss 0.0000 train_accu 1.0000 valid_loss 0.0107 valid_accu 0.9745
# 183  train_loss 0.0000 train_accu 1.0000 valid_loss 0.0103 valid_accu 0.9745
# 184  train_loss 0.0000 train_accu 1.0000 valid_loss 0.0096 valid_accu 0.9769
# 185  train_loss 0.0000 train_accu 1.0000 valid_loss 0.0112 valid_accu 0.9745
# 186  train_loss 0.0000 train_accu 1.0000 valid_loss 0.0129 valid_accu 0.9697
# 187  train_loss 0.0000 train_accu 1.0000 valid_loss 0.0081 valid_accu 0.9830
# 188  train_loss 0.0000 train_accu 1.0000 valid_loss 0.0084 valid_accu 0.9794
# 189  train_loss 0.0000 train_accu 1.0000 valid_loss 0.0066 valid_accu 0.9830
# 190  train_loss 0.0000 train_accu 1.0000 valid_loss 0.0090 valid_accu 0.9782
# 191  train_loss 0.0000 train_accu 1.0000 valid_loss 0.0153 valid_accu 0.9648
# 192  train_loss 0.0000 train_accu 1.0000 valid_loss 0.0077 valid_accu 0.9830
# 193  train_loss 0.0000 train_accu 1.0000 valid_loss 0.0093 valid_accu 0.9769
# 194  train_loss 0.0005 train_accu 0.9992 valid_loss 0.0189 valid_accu 0.9587
# 195  train_loss 0.0000 train_accu 1.0000 valid_loss 0.0064 valid_accu 0.9854
# 196  train_loss 0.0000 train_accu 1.0000 valid_loss 0.0085 valid_accu 0.9794
# 197  train_loss 0.0000 train_accu 1.0000 valid_loss 0.0080 valid_accu 0.9806
# 198  train_loss 0.0000 train_accu 1.0000 valid_loss 0.0071 valid_accu 0.9830
# 199  train_loss 0.0000 train_accu 1.0000 valid_loss 0.0079 valid_accu 0.9806
# 200  train_loss 0.0001 train_accu 0.9996 valid_loss 0.0120 valid_accu 0.9721
# Training done, save model at valid_accu = 0.9902912378311157

# %%
## 檢驗最佳模型在測試組資料的準確度
model = torch.load('gvd_detect.pt')

test_predict = torch.tensor([])
test_result = torch.tensor([])
for xb, yb in test_dl:
    test_predict = torch.cat([test_predict, model(xb)], 0)
    test_result = torch.cat([test_result, yb], 0)
print('test lost:', float(criterion(test_predict, test_result)))
print('test accu:', float(accuracy(test_predict, test_result)))
# Out:
# test lost: 0.0026078438386321068
# test accu: 0.9914004802703857

# %%
## 對前面有dropout的Linear層剪枝(pruning)
model = torch.load('gvd_detect.pt')

module = model.classifier[2]
prune.random_unstructured(module, name="weight", amount=0.7)
module._forward_pre_hooks
prune.remove(module,'weight')
module = model.classifier[6]
prune.random_unstructured(module, name="weight", amount=0.7)
module._forward_pre_hooks
prune.remove(module,'weight')

test_predict = torch.tensor([])
test_result = torch.tensor([])
for xb, yb in test_dl:
    test_predict = torch.cat([test_predict, model(xb)], 0)
    test_result = torch.cat([test_result, yb], 0)
print('test lost:', float(criterion(test_predict, test_result)))
print('test accu:', float(accuracy(test_predict, test_result)))
torch.save(model, 'gvd_detect_pruned.pt')
# Out:
# test lost: 0.002651957329362631
# test accu: 0.9926289916038513
