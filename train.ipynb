# %%
from PIL import Image
import os, random

import copy
import cv2
import pandas as pd
import matplotlib.pyplot as plt
import torch
import torchvision.transforms as transforms
import torchvision.models as models

from model import *

# %%
## kaggle: Grapevine Disease Images
## https://www.kaggle.com/datasets/piyushmishra1999/plantvillage-grape

cuda_available =  torch.cuda.is_available()
print('torch version:', torch.__version__)
print('cuda available:', cuda_available)
if cuda_available:
    print('-> cuda version:', torch.version.cuda)
    print('-> cuda device:', torch.cuda.get_device_name())
device = torch.device("cuda:0" if cuda_available else "cpu")
# Out:
# torch version: 1.11.0+cu113
# cuda available: True
# -> cuda version: 11.3
# -> cuda device: NVIDIA GeForce GTX 1650 with Max-Q Design

# %%
loader = transforms.Compose([
	transforms.Resize(128),  # 缩放
	transforms.ToTensor()
]) 

def get_image_info(root = 'dataset'):
	# 取得檔案的位置、類別並分組
    dir = [x for x in os.listdir(root) if not os.path.isfile(x)]
    info = pd.DataFrame()
    for (i, f) in enumerate(dir):
        f_files = [x for x in os.listdir(os.path.join(root, f)) if not os.path.isfile(x)]
        f_info = pd.DataFrame({
            'name':[f]*len(f_files), 
            'loc':[i]*len(f_files), 
            'file':[os.path.join(root, f, x) for x in f_files], 
            'group':random.choices(['train', 'valid', 'test'], [6, 2, 2], k=len(f_files))
        })
        info = pd.concat([info, f_info])
    return info

def _image_loader(image_name):
	image = Image.open(image_name)
	image = loader(image).unsqueeze(0)
	return image

def _get_image_x(x_data):
	x_data = x_data['file'].to_list()
	x_tensor = torch.tensor([])
	for x_d in x_data:
		x_image = _image_loader(x_d)
		x_tensor = torch.cat([x_tensor, x_image])
	return x_tensor

def _get_image_y(y_data, total=4):
	y_data = y_data['loc'].to_list()
	y_tensor = torch.tensor([])
	for y_d in y_data:
		y_list = [0.0] * total
		y_list[int(y_d)] = 1.0
		y_list = torch.tensor([y_list])
		y_tensor = torch.cat([y_tensor, y_list])
	return y_tensor

def get_image_data(info):
	data_train, data_valid, data_test = map(lambda x: info[info['group'] == x], ('train', 'valid', 'test'))
	x_train, x_valid, x_test = map(lambda x: _get_image_x(x), (data_train, data_valid, data_test))
	y_train, y_valid, y_test = map(lambda y: _get_image_y(y), (data_train, data_valid, data_test))
	return x_train, y_train, x_valid, y_valid, x_test, y_test

# %%
info = get_image_info()
x_train, y_train, x_valid, y_valid, x_test, y_test = get_image_data(info)

print(x_train.size(), y_train.size())
print(x_valid.size(), y_valid.size())
# Out:
# torch.Size([2419, 3, 128, 128]) torch.Size([2419, 4])
# torch.Size([849, 3, 128, 128]) torch.Size([849, 4])

# %%
model = gvd_detect()
train_dl = torch.utils.data.DataLoader(torch.utils.data.TensorDataset(x_train, y_train), shuffle=True, batch_size=64, pin_memory=True)
valid_dl = torch.utils.data.DataLoader(torch.utils.data.TensorDataset(x_valid, y_valid), shuffle=True, batch_size=64, pin_memory=True)

criterion = torch.nn.MSELoss(reduction='mean')
criterion = criterion.to(device)
optimizer = torch.optim.Adam(model.parameters())

maxVA = 0
maxVA_ep = 0

epoch = 1000
for e in range(epoch):
    ep = e+1
    model.train()
    model = model.to(device)
    for xb, yb in train_dl:
        pred = model(xb.to(device))
        loss = criterion(pred, yb.to(device))
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
    ## 模型評估
    model.eval()
    model = model.to(torch.device('cpu'))
    train_predict = torch.tensor([])
    train_result = torch.tensor([])
    for xb, yb in train_dl:
        train_predict = torch.cat([train_predict, model(xb)], 0)
        train_result = torch.cat([train_result, yb], 0)
    valid_predict = torch.tensor([])
    valid_result = torch.tensor([])
    for xb, yb in valid_dl:
        valid_predict = torch.cat([valid_predict, model(xb)], 0)
        valid_result = torch.cat([valid_result, yb], 0)
    
    train_loss = float(criterion(train_predict, train_result))
    valid_loss = float(criterion(valid_predict, valid_result))
    train_accu = float(accuracy(train_predict, train_result))
    valid_accu = float(accuracy(valid_predict, valid_result))

    save = ''
    if (maxVA < valid_accu) | (maxVA_ep < 1):
        maxVA = valid_accu
        maxVA_ep = ep
        save = '< save'
        torch.save(model, 'gvd_detect.pt')
    print('{:<4d}'.format(ep), 
        'train_loss', '{:.4f}'.format(train_loss), 
        'train_accu', '{:.4f}'.format(train_accu), 
        'valid_loss', '{:.4f}'.format(valid_loss), 
        'valid_accu', '{:.4f}'.format(valid_accu), 
        save)
    ## early drop
    if ep < 200: ## 至少執行200次
        pass
    elif maxVA_ep < ep/2: ## 連續一半epoch的準確度小於maxValAcc
        print('Accuracy of validation is CRASH !!')
        break
print('Training done, save model at VA =', maxVA)
# Out:
# 1    train_loss 0.1818 train_accu 0.2934 valid_loss 0.1821 valid_accu 0.2893 < save
# 2    train_loss 0.1802 train_accu 0.3460 valid_loss 0.1809 valid_accu 0.3321 < save
# 3    train_loss 0.1818 train_accu 0.3460 valid_loss 0.1829 valid_accu 0.3321
# 4    train_loss 0.1329 train_accu 0.5696 valid_loss 0.1325 valid_accu 0.5702 < save
# 5    train_loss 0.1241 train_accu 0.6101 valid_loss 0.1248 valid_accu 0.6238 < save
# 6    train_loss 0.0891 train_accu 0.7300 valid_loss 0.0976 valid_accu 0.6988 < save
# 7    train_loss 0.0808 train_accu 0.7639 valid_loss 0.0885 valid_accu 0.7250 < save
# 8    train_loss 0.0693 train_accu 0.8216 valid_loss 0.0768 valid_accu 0.7929 < save
# 9    train_loss 0.0956 train_accu 0.7183 valid_loss 0.1028 valid_accu 0.6976
# 10   train_loss 0.0522 train_accu 0.8588 valid_loss 0.0627 valid_accu 0.8262 < save
# 11   train_loss 0.0501 train_accu 0.8688 valid_loss 0.0597 valid_accu 0.8429 < save
# 12   train_loss 0.0429 train_accu 0.8863 valid_loss 0.0538 valid_accu 0.8488 < save
# 13   train_loss 0.0551 train_accu 0.8466 valid_loss 0.0652 valid_accu 0.8179
# 14   train_loss 0.0779 train_accu 0.7647 valid_loss 0.0913 valid_accu 0.7298
# 15   train_loss 0.0407 train_accu 0.8868 valid_loss 0.0529 valid_accu 0.8488
# 16   train_loss 0.0389 train_accu 0.8926 valid_loss 0.0498 valid_accu 0.8667 < save
train_loss 0.0000 train_accu 1.0000 valid_loss 0.0055 valid_accu 0.9833
# 112  train_loss 0.0010 train_accu 0.9979 valid_loss 0.0138 valid_accu 0.9631
# 113  train_loss 0.0003 train_accu 0.9992 valid_loss 0.0060 valid_accu 0.9845
# 114  train_loss 0.0000 train_accu 1.0000 valid_loss 0.0085 valid_accu 0.9798
# 115  train_loss 0.0003 train_accu 0.9992 valid_loss 0.0090 valid_accu 0.9786
# 116  train_loss 0.0003 train_accu 0.9992 valid_loss 0.0095 valid_accu 0.9762
# 117  train_loss 0.0001 train_accu 0.9996 valid_loss 0.0042 valid_accu 0.9893 < save
# 118  train_loss 0.0000 train_accu 1.0000 valid_loss 0.0066 valid_accu 0.9845
# 119  train_loss 0.0000 train_accu 1.0000 valid_loss 0.0034 valid_accu 0.9917 < save
# 120  train_loss 0.0000 train_accu 1.0000 valid_loss 0.0078 valid_accu 0.9821
# 121  train_loss 0.0000 train_accu 1.0000 valid_loss 0.0072 valid_accu 0.9833
# 122  train_loss 0.0053 train_accu 0.9887 valid_loss 0.0189 valid_accu 0.9548
# 123  train_loss 0.0007 train_accu 0.9983 valid_loss 0.0089 valid_accu 0.9786
# 124  train_loss 0.0005 train_accu 0.9987 valid_loss 0.0140 valid_accu 0.9655
# 125  train_loss 0.0030 train_accu 0.9921 valid_loss 0.0127 valid_accu 0.9619
# 126  train_loss 0.0017 train_accu 0.9958 valid_loss 0.0137 valid_accu 0.9702
# 127  train_loss 0.0012 train_accu 0.9975 valid_loss 0.0149 valid_accu 0.9667
# 128  train_loss 0.0078 train_accu 0.9812 valid_loss 0.0230 valid_accu 0.9440
# 129  train_loss 0.0000 train_accu 1.0000 valid_loss 0.0080 valid_accu 0.9821
# 130  train_loss 0.0001 train_accu 0.9996 valid_loss 0.0079 valid_accu 0.9810
# 131  train_loss 0.0001 train_accu 1.0000 valid_loss 0.0065 valid_accu 0.9821
# 132  train_loss 0.0000 train_accu 1.0000 valid_loss 0.0071 valid_accu 0.9810
# 133  train_loss 0.0000 train_accu 1.0000 valid_loss 0.0080 valid_accu 0.9821
# 134  train_loss 0.0000 train_accu 1.0000 valid_loss 0.0079 valid_accu 0.9810
# 135  train_loss 0.0075 train_accu 0.9804 valid_loss 0.0190 valid_accu 0.9512
# 136  train_loss 0.0000 train_accu 1.0000 valid_loss 0.0091 valid_accu 0.9774
# 137  train_loss 0.0000 train_accu 1.0000 valid_loss 0.0076 valid_accu 0.9833
# 138  train_loss 0.0011 train_accu 0.9979 valid_loss 0.0076 valid_accu 0.9821
# 139  train_loss 0.0001 train_accu 1.0000 valid_loss 0.0112 valid_accu 0.9762
# 140  train_loss 0.0001 train_accu 1.0000 valid_loss 0.0085 valid_accu 0.9810
# 141  train_loss 0.0002 train_accu 0.9996 valid_loss 0.0083 valid_accu 0.9810
# 142  train_loss 0.0001 train_accu 1.0000 valid_loss 0.0069 valid_accu 0.9833
# 143  train_loss 0.0003 train_accu 0.9996 valid_loss 0.0140 valid_accu 0.9667
# 144  train_loss 0.0000 train_accu 1.0000 valid_loss 0.0070 valid_accu 0.9821
# 145  train_loss 0.0000 train_accu 1.0000 valid_loss 0.0077 valid_accu 0.9774
# 146  train_loss 0.0003 train_accu 0.9996 valid_loss 0.0160 valid_accu 0.9619
# 147  train_loss 0.0000 train_accu 1.0000 valid_loss 0.0070 valid_accu 0.9821
# 148  train_loss 0.0000 train_accu 1.0000 valid_loss 0.0072 valid_accu 0.9833
# 149  train_loss 0.0000 train_accu 1.0000 valid_loss 0.0065 valid_accu 0.9845
# 150  train_loss 0.0006 train_accu 0.9983 valid_loss 0.0128 valid_accu 0.9690
# 151  train_loss 0.0008 train_accu 0.9979 valid_loss 0.0103 valid_accu 0.9750
# 152  train_loss 0.0000 train_accu 1.0000 valid_loss 0.0074 valid_accu 0.9833
# 153  train_loss 0.0000 train_accu 1.0000 valid_loss 0.0077 valid_accu 0.9810
# 154  train_loss 0.0000 train_accu 1.0000 valid_loss 0.0064 valid_accu 0.9845
# 155  train_loss 0.0001 train_accu 0.9996 valid_loss 0.0085 valid_accu 0.9798
# 156  train_loss 0.0000 train_accu 1.0000 valid_loss 0.0071 valid_accu 0.9845
# 157  train_loss 0.0000 train_accu 1.0000 valid_loss 0.0089 valid_accu 0.9798
# 158  train_loss 0.0000 train_accu 1.0000 valid_loss 0.0076 valid_accu 0.9833
# 159  train_loss 0.0001 train_accu 1.0000 valid_loss 0.0092 valid_accu 0.9786
# 160  train_loss 0.0008 train_accu 0.9979 valid_loss 0.0105 valid_accu 0.9714
# 161  train_loss 0.0001 train_accu 0.9996 valid_loss 0.0057 valid_accu 0.9845
# 162  train_loss 0.0011 train_accu 0.9962 valid_loss 0.0101 valid_accu 0.9774
# 163  train_loss 0.0000 train_accu 1.0000 valid_loss 0.0057 valid_accu 0.9881
# 164  train_loss 0.0009 train_accu 0.9975 valid_loss 0.0067 valid_accu 0.9869
# 165  train_loss 0.0001 train_accu 0.9996 valid_loss 0.0082 valid_accu 0.9798
# 166  train_loss 0.0014 train_accu 0.9958 valid_loss 0.0192 valid_accu 0.9583
# 167  train_loss 0.0001 train_accu 0.9996 valid_loss 0.0077 valid_accu 0.9798
# 168  train_loss 0.0017 train_accu 0.9967 valid_loss 0.0177 valid_accu 0.9595
# 169  train_loss 0.0000 train_accu 1.0000 valid_loss 0.0070 valid_accu 0.9845
# 170  train_loss 0.0003 train_accu 0.9992 valid_loss 0.0061 valid_accu 0.9833
# 171  train_loss 0.0000 train_accu 1.0000 valid_loss 0.0081 valid_accu 0.9821
# 172  train_loss 0.0000 train_accu 1.0000 valid_loss 0.0056 valid_accu 0.9869
# 173  train_loss 0.0025 train_accu 0.9937 valid_loss 0.0117 valid_accu 0.9726
# 174  train_loss 0.0007 train_accu 0.9975 valid_loss 0.0116 valid_accu 0.9750
# 175  train_loss 0.0000 train_accu 1.0000 valid_loss 0.0065 valid_accu 0.9869
# 176  train_loss 0.0000 train_accu 1.0000 valid_loss 0.0056 valid_accu 0.9893
# 177  train_loss 0.0011 train_accu 0.9967 valid_loss 0.0141 valid_accu 0.9619
# 178  train_loss 0.0000 train_accu 1.0000 valid_loss 0.0067 valid_accu 0.9845
# 179  train_loss 0.0000 train_accu 1.0000 valid_loss 0.0058 valid_accu 0.9881
# 180  train_loss 0.0000 train_accu 1.0000 valid_loss 0.0066 valid_accu 0.9857
# 181  train_loss 0.0000 train_accu 1.0000 valid_loss 0.0097 valid_accu 0.9762
# 182  train_loss 0.0000 train_accu 1.0000 valid_loss 0.0067 valid_accu 0.9857
# 183  train_loss 0.0000 train_accu 1.0000 valid_loss 0.0076 valid_accu 0.9821
# 184  train_loss 0.0000 train_accu 1.0000 valid_loss 0.0081 valid_accu 0.9810
# 185  train_loss 0.0002 train_accu 0.9996 valid_loss 0.0070 valid_accu 0.9857
# 186  train_loss 0.0000 train_accu 1.0000 valid_loss 0.0099 valid_accu 0.9762
# 187  train_loss 0.0000 train_accu 1.0000 valid_loss 0.0087 valid_accu 0.9798
# 188  train_loss 0.0000 train_accu 1.0000 valid_loss 0.0085 valid_accu 0.9798
# 189  train_loss 0.0000 train_accu 1.0000 valid_loss 0.0067 valid_accu 0.9845
# 190  train_loss 0.0000 train_accu 1.0000 valid_loss 0.0051 valid_accu 0.9869
# 191  train_loss 0.0000 train_accu 1.0000 valid_loss 0.0076 valid_accu 0.9833
# 192  train_loss 0.0008 train_accu 0.9979 valid_loss 0.0106 valid_accu 0.9738
# 193  train_loss 0.0000 train_accu 1.0000 valid_loss 0.0065 valid_accu 0.9821
# 194  train_loss 0.0000 train_accu 1.0000 valid_loss 0.0082 valid_accu 0.9810
# 195  train_loss 0.0000 train_accu 1.0000 valid_loss 0.0058 valid_accu 0.9845
# 196  train_loss 0.0000 train_accu 1.0000 valid_loss 0.0039 valid_accu 0.9893
# 197  train_loss 0.0000 train_accu 1.0000 valid_loss 0.0122 valid_accu 0.9702
# 198  train_loss 0.0001 train_accu 1.0000 valid_loss 0.0111 valid_accu 0.9726
# 199  train_loss 0.0002 train_accu 0.9996 valid_loss 0.0071 valid_accu 0.9821
# 200  train_loss 0.0000 train_accu 1.0000 valid_loss 0.0041 valid_accu 0.9881
# 201  train_loss 0.0000 train_accu 1.0000 valid_loss 0.0084 valid_accu 0.9786
# 202  train_loss 0.0025 train_accu 0.9933 valid_loss 0.0182 valid_accu 0.9560
# 203  train_loss 0.0000 train_accu 1.0000 valid_loss 0.0081 valid_accu 0.9833
# 204  train_loss 0.0009 train_accu 0.9975 valid_loss 0.0124 valid_accu 0.9702
# 205  train_loss 0.0006 train_accu 0.9987 valid_loss 0.0053 valid_accu 0.9881
# 206  train_loss 0.0000 train_accu 1.0000 valid_loss 0.0054 valid_accu 0.9869
# 207  train_loss 0.0000 train_accu 1.0000 valid_loss 0.0072 valid_accu 0.9845
# 208  train_loss 0.0000 train_accu 1.0000 valid_loss 0.0051 valid_accu 0.9893
# 209  train_loss 0.0000 train_accu 1.0000 valid_loss 0.0049 valid_accu 0.9869
# 210  train_loss 0.0000 train_accu 1.0000 valid_loss 0.0060 valid_accu 0.9857
# 211  train_loss 0.0000 train_accu 1.0000 valid_loss 0.0052 valid_accu 0.9869
# 212  train_loss 0.0002 train_accu 0.9992 valid_loss 0.0081 valid_accu 0.9786
# 213  train_loss 0.0000 train_accu 1.0000 valid_loss 0.0058 valid_accu 0.9869
# 214  train_loss 0.0000 train_accu 1.0000 valid_loss 0.0065 valid_accu 0.9857
# 215  train_loss 0.0000 train_accu 1.0000 valid_loss 0.0069 valid_accu 0.9845
# 216  train_loss 0.0001 train_accu 0.9996 valid_loss 0.0072 valid_accu 0.9833
# 217  train_loss 0.0000 train_accu 1.0000 valid_loss 0.0050 valid_accu 0.9893
# 218  train_loss 0.0005 train_accu 0.9987 valid_loss 0.0074 valid_accu 0.9821
# 219  train_loss 0.0003 train_accu 0.9992 valid_loss 0.0064 valid_accu 0.9845
# 220  train_loss 0.0005 train_accu 0.9987 valid_loss 0.0085 valid_accu 0.9821
# 221  train_loss 0.0000 train_accu 1.0000 valid_loss 0.0055 valid_accu 0.9881
# 222  train_loss 0.0006 train_accu 0.9987 valid_loss 0.0111 valid_accu 0.9762
# 223  train_loss 0.0019 train_accu 0.9954 valid_loss 0.0152 valid_accu 0.9655
# 224  train_loss 0.0014 train_accu 0.9967 valid_loss 0.0130 valid_accu 0.9667
# 225  train_loss 0.0044 train_accu 0.9896 valid_loss 0.0222 valid_accu 0.9500
# 226  train_loss 0.0003 train_accu 0.9992 valid_loss 0.0071 valid_accu 0.9833
# 227  train_loss 0.0001 train_accu 1.0000 valid_loss 0.0084 valid_accu 0.9798
# 228  train_loss 0.0020 train_accu 0.9958 valid_loss 0.0107 valid_accu 0.9750
# 229  train_loss 0.0061 train_accu 0.9862 valid_loss 0.0200 valid_accu 0.9548
# 230  train_loss 0.0021 train_accu 0.9954 valid_loss 0.0114 valid_accu 0.9714
# 231  train_loss 0.0000 train_accu 1.0000 valid_loss 0.0078 valid_accu 0.9821
# 232  train_loss 0.0006 train_accu 0.9987 valid_loss 0.0109 valid_accu 0.9738
# 233  train_loss 0.0095 train_accu 0.9795 valid_loss 0.0252 valid_accu 0.9429
# 234  train_loss 0.0005 train_accu 0.9979 valid_loss 0.0103 valid_accu 0.9738
# 235  train_loss 0.0000 train_accu 1.0000 valid_loss 0.0068 valid_accu 0.9845
# 236  train_loss 0.0000 train_accu 1.0000 valid_loss 0.0068 valid_accu 0.9845
# 237  train_loss 0.0002 train_accu 0.9996 valid_loss 0.0101 valid_accu 0.9774
# 238  train_loss 0.0000 train_accu 1.0000 valid_loss 0.0081 valid_accu 0.9845
# 239  train_loss 0.0000 train_accu 1.0000 valid_loss 0.0070 valid_accu 0.9845
# Accuracy of validation is CRASH !!
# Training done, save model at VA = 0.9916666746139526

# %%
mdel = torch.load('gvd_detect.pt')
test_dl = torch.utils.data.DataLoader(torch.utils.data.TensorDataset(x_test, y_test), shuffle=True, batch_size=64, pin_memory=True)
test_predict = torch.tensor([])
test_result = torch.tensor([])
for xb, yb in test_dl:
    valid_predict = torch.cat([test_predict, model(xb)], 0)
    valid_result = torch.cat([test_result, yb], 0)
print('test lost:', float(criterion(valid_predict, valid_result)))
print('test accu:', float(accuracy(train_predict, train_result)))
# Out:
# test lost: 1.3230186368673458e-07
# test accu: 1.0
